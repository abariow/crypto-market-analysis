# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/Coins.csv')
df.head()
# Out:
#    Rank         Name Symbol                                        MainLink  \
# 0     1      Bitcoin    BTC   https://coinmarketcap.com/currencies/bitcoin/
# 1     2     Ethereum    ETH  https://coinmarketcap.com/currencies/ethereum/
# 2     3  Tether USDt   USDT    https://coinmarketcap.com/currencies/tether/
# 3     4          BNB    BNB       https://coinmarketcap.com/currencies/bnb/
# 4     5          XRP    XRP       https://coinmarketcap.com/currencies/xrp/
#
#                                       HistoricalLink  \
# 0  https://coinmarketcap.com/currencies/bitcoin/h...
# 1  https://coinmarketcap.com/currencies/ethereum/...
# 2  https://coinmarketcap.com/currencies/tether/hi...
# 3  https://coinmarketcap.com/currencies/bnb/histo...
# 4  https://coinmarketcap.com/currencies/xrp/histo...
#
#                                github_link  \
# 0       https://github.com/bitcoin/bitcoin
# 1  https://github.com/ethereum/go-ethereum
# 2                                      NaN
# ...

# %%
tags = df[['tags']]
tags.head(50)
# Out:
#                                                  tags
# 0                      ['Mineable', 'PoW', 'SHA-256']
# 1    ['PoS', 'Smart Contracts', 'Ethereum Ecosystem']
# 2   ['Payments', 'Stablecoin', 'Asset-Backed Stabl...
# 3   ['Marketplace', 'Centralized Exchange (CEX) To...
# 4   ['Medium of Exchange', 'Enterprise Solutions',...
# 5   ['Medium of Exchange', 'Stablecoin', 'Asset-Ba...
# 6                         ['DPoS', 'PoS', 'Platform']
# 7                       ['Mineable', 'PoW', 'Scrypt']
# 8             ['PoS', 'Platform', 'Solana Ecosystem']
# 9             ['Media', 'Payments', 'TRON Ecosystem']
# 10         ['Substrate', 'Polkadot', 'Binance Chain']
# 11  ['DeFi', 'Stablecoin', 'Asset-Backed Stablecoin']
# 12        ['PoS', 'Platform', 'Enterprise Solutions']
# 13  ['PoS', 'DWF Labs Portfolio', 'Toncoin Ecosyst...
# 14                      ['Mineable', 'PoW', 'Scrypt']
# 15  ['Memes', 'Ethereum Ecosystem', 'Doggone Dogge...
# ...

# %%
clean_tags = tags.explode()
# Out:
# tags    ['Mineable', 'PoW', 'SHA-256']
# Name: 0, dtype: object
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_83326/1271848284.py in ?()
#       2 clean_tags = pd.Series()
#       3 for index, tag_list in tags.iterrows():
#       4     print(f"{tag_list}\n\n")
#       5     for tag in tag_list:
# ----> 6         s = pd.Series(tag)
#       7         f = clean_tags.append(s)
#       8 print(f)
#
# ~/anaconda3/envs/quera/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'append'
